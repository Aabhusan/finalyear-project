# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("bowler_1.csv")

# %%
dataset = dataset.fillna(0)
dataset
# Out:
#                       name           mt  Mat   Inns  Balls   Runs  Wkts  \
# 0            Praveen Kumar  First-class   66  121.0  14158   6306   267
# 1            Praveen Kumar       List A  139    0.0   6730   5336   185
# 2            Praveen Kumar         T20s  177  177.0   3695   4599   143
# 3            Akshdeep Nath  First-class   22   12.0    366    179     6
# 4            Akshdeep Nath       List A   44   14.0    360    327    13
# 5            Akshdeep Nath         T20s   51   15.0    177    241    12
# 6              Amit Mishra  First-class  152    0.0  30843  15608   535
# 7              Amit Mishra       List A  144    0.0   7426   5681   242
# 8              Amit Mishra         T20s  199  198.0   4168   4970   228
# 9            Piyush Chawla  First-class  130  227.0  26086  14276   437
# 10           Piyush Chawla       List A  131  127.0   6487   5363   208
# 11           Piyush Chawla         T20s  208  207.0   4290   5379   218
# ...

# %%
y = dataset.iloc[: , -1]
#y

# %%
X = dataset.iloc[: , 0:13]
# X

# %%
name = dataset.iloc[: ,0 ]
#name

# %%
mt = X.iloc[:,1]
#mt

# %%
dataset
# Out:
#                       name           mt  Mat   Inns  Balls   Runs  Wkts  \
# 0            Praveen Kumar  First-class   66  121.0  14158   6306   267
# 1            Praveen Kumar       List A  139    0.0   6730   5336   185
# 2            Praveen Kumar         T20s  177  177.0   3695   4599   143
# 3            Akshdeep Nath  First-class   22   12.0    366    179     6
# 4            Akshdeep Nath       List A   44   14.0    360    327    13
# 5            Akshdeep Nath         T20s   51   15.0    177    241    12
# 6              Amit Mishra  First-class  152    0.0  30843  15608   535
# 7              Amit Mishra       List A  144    0.0   7426   5681   242
# 8              Amit Mishra         T20s  199  198.0   4168   4970   228
# 9            Piyush Chawla  First-class  130  227.0  26086  14276   437
# 10           Piyush Chawla       List A  131  127.0   6487   5363   208
# 11           Piyush Chawla         T20s  208  207.0   4290   5379   218
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_x = LabelEncoder()
mt_new = labelencoder_x.fit_transform(mt)
X.iloc[:,1]= mt_new.astype(int)

# %%
# preprocess :  categorical variable
from sklearn.preprocessing import LabelEncoder
labelencoder_x = LabelEncoder()
name_new = labelencoder_x.fit_transform(name)
X.iloc[:,0]=name_new.astype(int)
dataset.iloc[:,0] = name_new.astype(int)

# %%
a = X.name.unique()
a.sort()

# %%
# from sklearn.preprocessing  import OneHotEncoder
# onehotencoder = OneHotEncoder(categorical_features=[0])
# X = onehotencoder.fit_transform(X).toarray()

# %%
# from sklearn.preprocessing  import OneHotEncoder
# onehotencoder = OneHotEncoder(categorical_features=[1])
# X = onehotencoder.fit_transform(X).toarray()

# %%
dataset
# Out:
#      name           mt  Mat   Inns  Balls   Runs  Wkts    Ave   Econ     SR  \
# 0      19  First-class   66  121.0  14158   6306   267  23.61   2.67   53.0
# 1      19       List A  139    0.0   6730   5336   185  28.84   4.75   36.3
# 2      19         T20s  177  177.0   3695   4599   143  32.16   7.46   25.8
# 3       0  First-class   22   12.0    366    179     6  29.83   2.93   61.0
# 4       0       List A   44   14.0    360    327    13  25.15   5.45   27.6
# 5       0         T20s   51   15.0    177    241    12  20.08   8.16   14.7
# 6       1  First-class  152    0.0  30843  15608   535  29.17   3.03   57.6
# 7       1       List A  144    0.0   7426   5681   242  23.47   4.59   30.6
# 8       1         T20s  199  198.0   4168   4970   228  21.79   7.15   18.2
# 9      17  First-class  130  227.0  26086  14276   437  32.66   3.28   59.6
# 10     17       List A  131  127.0   6487   5363   208  25.78   4.96   31.1
# ...

# %%
dataset.iloc[:,1]=mt_new 
#mt_new

# %%
# from sklearn.preprocessing  import OneHotEncoder
# onehotencoder = OneHotEncoder( categorical_features=[1])
# X = onehotencoder.fit_transform(X).toarray()

# %%
X[X["name"]==12]
# Out:
#     name  mt  Mat  Inns  Balls  Runs  Wkts    Ave  Econ    SR   4w   5w  10
# 58    12   0   30  49.0   5774  3512   117  30.01  3.64  49.3  7.0  6.0   0
# 59    12   1   44  42.0   2274  1777    83  21.40  4.68  27.3  2.0  2.0   0
# 60    12   2   79  78.0   1695  2073   106  19.55  7.33  15.9  3.0  2.0   0

# %%
#import itertools
#features = []
#for i in a:
    #features.append(list(itertools.chain(*X[X["name"]==i].iloc[:,2:].values)))
#features=pd.DataFrame(features)
#features

# %%
targets = []
for i in a:
    targets.append(any(dataset[dataset["name"]==i]["capped"]))
#targets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegressionCV

model = LogisticRegressionCV()

# %%
model.fit(X_train ,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-773451047db3> in <module>()
# ----> 1 model.fit(X_train ,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1609
#    1610         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1611                          order="C")
#    1612         check_classification_targets(y)
#    1613
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# ...

# %%
model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-24-4bc81fc0de58> in <module>()
# ----> 1 model.predict(X_test)
#       2
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     322             Predicted class label per sample.
#     323         """
# --> 324         scores = self.decision_function(X)
#     325         if len(scores.shape) == 1:
#     326             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     296         if not hasattr(self, 'coef_') or self.coef_ is None:
#     297             raise NotFittedError("This %(name)s instance is not fitted "
# --> 298                                  "yet" % {'name': type(self).__name__})
#     299
#     300         X = check_array(X, accept_sparse='csr')
#
# ...

# %%
y_test
# Out:
# [False, False, False, False, True, True, True, False, True, True]
