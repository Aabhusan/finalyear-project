# %%
import socket
import pyttsx3

s=socket.socket()
x=s.connect(("192.168.43.222",4444))
if (x) == None:

    #print("welcome to my tool ")
    engine=pyttsx3.init()
    engine.say("welcome to my tool")
    print("""
    press1: to setup web server
    press2: to setup docker
    press3: to setup hadoop
    """)

    engine.say("""
    press 1: to setup web server
    press 2: to setup docker
    press 3: to setup hadoop
    """)

    #print("please tell me your choice:")
    #ch=input()
    engine.say("please tell me your choice:")
    engine.runAndWait()



    import speech_recognition as sr

    mic =sr.Microphone() # mic source

    rec=sr.Recognizer() #recognize

    rec.recognize_google # send speech to google
    ch ="1"
    with mic as source:
        engine.say("say :")
        engine.runAndWait()
        audio = rec.listen(source)
        text = rec.recognize_google(audio) #send to google
        print(text) # google wll recognize and send text.

    if "setup" in text and "web server" in text:
        ch ="1"
        engine.say("your choice is 1")
        engine.runAndWait()
    elif "setup" in text and "docker" in text:
        ch ="2"
        engine.say("your choice is 2")
        engine.runAndWait()
    elif "setup" in text and "hadoop" in text:
        ch ="3"
        engine.say("your choice is 3")
        engine.runAndWait()
    else:
        ch = "0"
        engine.say("do not understand")
        engine.runAndWait()

    ch=ch.encode()
    s.send(ch)
    ch=s.recv(20)
    op=ch.decode()
    print(op)
    
    

    engine.say("succesfully executed")
    engine.runAndWait()
# Out:
#     press1: to setup web server
#     press2: to setup docker
#     press3: to setup hadoop
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# ...
